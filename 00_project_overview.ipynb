# %% [markdown]
# # 🧠 Project Overview
#
# Welcome to **Critical Workforce Analytics**.
#
# This notebook provides a high-level overview of the project's purpose, structure, and current progress.
#
# ## 📌 Project Goals
# - Deconstruct standard HR metrics using data science and critical theory
# - Visualize the impact of metric construction on workforce perception
# - Explore new taxonomies of value and influence in retail labor
#
# ## 🗂️ Project Structure
# ```
# ├── data/           # Raw and processed datasets
# ├── notebooks/      # Jupyter notebooks for analysis
# ├── dashboards/     # Dashboard apps (e.g., Dash or Streamlit)
# ├── reports/        # Written analysis and executive summaries
# ```
#
# ## ✅ Next Steps
# - Import datasets into `data/raw/`
# - Begin exploring metrics in a new notebook
# - Build first visualizations and narrative reflections
